# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
imagen = imread("img/python.jpg")

# %%
imagen
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(imagen)

# %%
plt.imshow(imagen[:,:,0], cmap="Reds")

# %%
plt.imshow(imagen[:,:,1], cmap="Blues")

# %%
plt.imshow(imagen[:,:,2], cmap="Greens")

# %%
img_crop = imagen

# %%
img_crop[50:250,250:456] = [25,255,25]

# %%
plt.imshow(img_crop)
