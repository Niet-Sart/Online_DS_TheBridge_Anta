# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION Y PRESENTACION

# %% [markdown]
# * La práctica obligatoria de esta unidad se divide en dos partes, una dedicada a visualización y construcción de funciones, y la otra a hacer una presentación de resultados. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0
#
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## #1 VISUALIZACION

# %% [markdown]
# ### #1.1
#
# Carga el dataset de las ciudades de California que está en la ruta "./data/california_cities.csv". Muestra su contenido, deshazte de las filas con nulos.

# %%
df_cities = pd.read_csv('./data/california_cities.csv', index_col=0)
df_cities.sample(30)
# Out:
#                 city       latd       longd  elevation_m  elevation_ft  \
# 216          LaPalma  33.849444 -118.043889         14.0          46.0
# 368         SanDimas  34.102778 -117.816111          NaN         750.0
# 183  HuntingtonBeach  33.692778 -118.000278         12.0          39.0
# 318           Pinole  38.004444 -122.291111         31.0          23.0
# 139         Fillmore  34.401389 -118.917778        139.0         456.0
# 397         Saratoga  37.272500 -122.019444          NaN         410.0
# 408       SimiValley  34.271111 -118.739444        234.0         768.0
# 182          Hughson  37.603056 -120.866944         38.0         125.0
# 222         Lawndale  33.886667 -118.353611         18.0          59.0
# 425      SutterCreek  38.393056 -120.802500        362.0        1188.0
# 230             Lodi  38.128889 -121.280833         15.0          50.0
# 412           Sonoma  38.288889 -122.458889         26.0          85.0
# 373       SanJacinto  33.787222 -116.966667        477.0        1565.0
# 214         LaMirada  33.902222 -118.009722         59.0         194.0
# 383         SanPablo  37.962222 -122.345556         16.0          52.0
# 380        SanMarcos  33.141944 -117.170278          NaN           NaN
# 424       Susanville  40.416389 -120.653056       1276.0        4186.0
# 232           Lomita  33.793333 -118.316111         29.0          95.0
# 219         Larkspur  37.934167 -122.535278          NaN          43.0
# 57        Calipatria  33.125556 -115.514167          NaN        -180.0
# 55    CaliforniaCity  35.125833 -117.985833        733.0        2405.0
# 348         RioVista  38.163889 -121.695833          6.0          20.0
# 303         Palmdale  34.581111 -118.100556        810.0        2657.0
# 244           Madera  36.961389 -120.060833         83.0         271.0
# 88           Compton  33.896667 -118.225000         21.0          69.0
# 381        SanMarino  34.122778 -118.113056        172.0         564.0
# 372           Sanger  36.708056 -119.555833          NaN         371.0
# 5         AlisoViejo  33.575000 -117.725556        127.0         417.0
# 433         Torrance  33.834722 -118.341389         27.0          89.0
# 428           Tehama  40.024444 -122.123889         64.0         210.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 216             15568             1.832            1.808             0.024
# 368             33371            15.427           15.037             0.390
# 183            197575            31.882           26.748             5.134
# 318             18390            13.575            5.323             8.252
# 139             15002             3.365            3.364             0.001
# 397             29926            12.382           12.382             0.000
# 408            126874            42.247           41.480             0.767
# 182              6640             1.815            1.815             0.000
# 222             32769             1.974            1.974             0.000
# 425              2501             2.558            2.558             0.000
# 230             62134            13.825           13.611             0.214
# 412             10648             2.742            2.742             0.000
# 373             44199            26.131           25.716             0.415
# 214             48527             7.857            7.840             0.017
# 383             29139             2.634            2.634             0.000
# 380             83781            24.390           24.370             0.020
# 424             17974             8.017            7.931             0.086
# 232             20256             1.911            1.911             0.000
# 219             11926             3.243            3.027             0.216
# 57               7705             3.716            3.716             0.000
# 55              14120           203.631          203.523             0.108
# 348              7360             7.094            6.691             0.403
# 303            152750           106.216          105.961             0.255
# 244             61416            15.789           15.789             0.000
# 88              96455            10.116           10.012             0.104
# 381             13147             3.774            3.767             0.007
# 372             24270             5.524            5.524             0.000
# 5               47823             7.472            7.472             0.000
# 433            147027            20.553           20.478             0.075
# 428               418             0.794            0.794             0.000
#
#      area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 216           4.744          4.682           0.063                1.32
# 368          39.957         38.947           1.010                2.53
# 183          82.576         69.278          13.298               16.10
# 318          35.160         13.787          21.372               60.79
# 139           8.715          8.712           0.003                0.03
# 397          32.070         32.070           0.000                0.00
# 408         109.418        107.433           1.986                1.81
# 182           4.701          4.701           0.000                0.00
# 222           5.113          5.113           0.000                0.00
# 425           6.625          6.625           0.000                0.00
# 230          35.805         35.252           0.553                1.54
# 412           7.102          7.102           0.000                0.00
# 373          67.679         66.605           1.074                1.59
# 214          20.351         20.306           0.045                0.22
# 383           6.822          6.822           0.000                0.00
# 380          63.169         63.117           0.053                0.08
# 424          20.763         20.541           0.222                1.07
# 232           4.949          4.949           0.000                0.00
# 219           8.399          7.840           0.560                6.66
# 57            9.624          9.624           0.000                0.00
# 55          527.401        527.122           0.279                0.05
# 348          18.375         17.330           1.044                5.68
# 303         275.099        274.439           0.660                0.24
# 244          40.894         40.894           0.000                0.00
# 88           26.202         25.932           0.270                1.03
# 381           9.775          9.757           0.018                0.18
# 372          14.307         14.307           0.000                0.00
# 5            19.352         19.352           0.000                0.00
# 433          53.233         53.038           0.195                0.37
# 428           2.057          2.057           0.000                0.00

# %%
df_cities.dropna(inplace=True)
df_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 427 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                427 non-null    object
#  1   latd                427 non-null    float64
#  2   longd               427 non-null    float64
#  3   elevation_m         427 non-null    float64
#  4   elevation_ft        427 non-null    float64
#  5   population_total    427 non-null    int64
#  6   area_total_sq_mi    427 non-null    float64
#  7   area_land_sq_mi     427 non-null    float64
#  8   area_water_sq_mi    427 non-null    float64
#  9   area_total_km2      427 non-null    float64
#  10  area_land_km2       427 non-null    float64
#  11  area_water_km2      427 non-null    float64
#  12  area_water_percent  427 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 46.7+ KB

# %% [markdown]
# ### #1.2
#
# Crea una función similar a la que se pide en el ejercicio 6 de la segunda tanda de ejercicios del workout. Es decir, una función para pintar diagramas de dispersion que tenga seis argumentos, pero ojo al cambio en el quinto:
# 1. Un dataframe
# 2. Una columna numérica del dataframe
# 3. Una columna numérica del dataframe diferente a la anterior.
# 4. Un columna categórica (Opcional, valor por defecto None)
# 5. Un valor para el tamaño de los puntos o una cadena, pero que puede ser una cadena de caracteres, en cuyo caso se debe interpretar como una de las columnas del dataframe cuyos valores deben controlar el tamaño
# 6. Un sexto argumento "escala", que permita manipular la escala del tamaño en el caso de que el quinto argumento sea una cadena. Este argumento multiplicará a los valores de la columna indicada en el parámetro anterior (así si quiero dividir por 10000, este sexto argumento tendrá que valer 1/10000)
#
# La función debe pintar el diagrama de dispersión de la columna numérica 1, en el eje X, frente a la columna numérica 2, en el eje Y, usando un código de colores en función de la columna categórica y con el tamaño de los puntos según el argumento correspondiente.
#
# Si no se diera una columna categórica como argumento, el color no debe pasarse como parámetro a la función de Seaborn o Matplotlib que uses.
#
# EXTRA: Añade un argumento que controle si la función pinta una leyenda para colores y tamaños o un colorbar y una leyenda para los tamaños. NO TE PREOCUPES POR EL FORMATO DE LA LEYENDA (lo veremos en la sesión en vivo)

# %%
def scatter_plot(df, col_num1, col_num2, col_cat=None, size=20, scale=1):
    plt.figure(figsize=(17, 8))
    
    if isinstance(size, str):
        size = df[size] * scale
    
    if col_cat!=None:
        plt.scatter(df[col_num1], df[col_num2], c=df[col_cat], s=size, cmap='viridis', alpha=0.6, edgecolors='w', linewidth=0.5)
    else:
        plt.scatter(df[col_num1], df[col_num2], s=size, alpha=0.6, edgecolors='w', linewidth=0.5)
    
    plt.xlabel(col_num1)
    plt.ylabel(col_num2)
    plt.title(f'Diagrama de dispersión {col_num1} vs {col_num2}')
    
    plt.show()

# %% [markdown]
# ### #1.3
#
# Pinta el diagrama de dispersión de longitud y latitud (longitud en las x, latitud en las y) de las ciudades, usando el tamaño de las ciudades para el tamaño de los puntos y los colores para mostrar la población. Previamente crea una columna nueva "log_poblacion" y asignale el log decimal de la poblacion (np.log10() y como argumento los valores de la columna "population_total"). Usa "log_poblacion" para el color.

# %% [markdown]
# Un ejemplo de como podría salir para que lo tengas de referencia: (olvidate de la leyenda, auque si quieres como extra puedes intentar ver cómo crearla así)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_cities['log_poblacion'] = np.log10(df_cities['population_total'])

scatter_plot(df_cities, 'longd', 'latd', 'log_poblacion', size='area_total_km2', scale=0.5)

# %% [markdown]
# ## #2: Presentación

# %% [markdown]
# En esta parte tendrás que hacer dos cosas, crear una presentación sobre el titanic de no más de 6 slides, sin incluir portada, con los siguientes mensajes y su apoyo en datos:
# 1- El titanic fue un accidente con una tasa de mortalidad alta.
# 2- En esa ocasión los datos apoyan que se dio el "Las mujeres y los niños primero", pero...
# 3- ... que la clase en la que se viajes tuvo una influencia significativa y podría explicar...
# 4- ... las diferencias de tasas de supervivencia entre mujeres y niños.
# 5- Además aunque el puerto de embarque parece influir, se podría asumir que lo fue el tipo de pasaje que embarcó en cada uno.

# %% [markdown]
# Y generar el notebook con las gráficas que vas a emplear en la presentación. Tienes que entregar ambas cosas.

# %%
df_titanic = pd.read_csv("data/titanic.csv")

# %%
data = df_titanic["alive"].value_counts()

fig,ax = plt.subplots(1,1,figsize = (4,4))

ax.pie(data.values,
        labels=["No sobrevivieron", "Sobrevivieron"],
        autopct='%.2f%%', startangle= 90,
        colors=["#FF4500","#00BAFF"])

my_circle=plt.Circle((0,0),0.5,color="white")
ax.set_title("Tasa de mortalidad", size="xx-large")
ax.text(0,-1.5,"La tasa de mortalidad fue del 61.62%.\nPor cada 2 personas que sobrevivieron, 3 murieron",
        fontsize=16, horizontalalignment="center")

ax.add_artist(my_circle);

fig.savefig("data/1.png", bbox_inches='tight')

# %%
# 2

data = df_titanic.groupby("who")["alive"].value_counts()

fig,ax = plt.subplots(1,3,figsize = (18,4))

leyendas = ["niños", "hombres", "mujeres"]

for i in range(int(len(data.values)/2)):
    ax[i].pie(data.values[i*2:(i+1)*2],
            labels=["No sobrevivieron", "Sobrevivieron"],
            autopct='%.2f%%', startangle= 90,
            colors=["#FF4500","#00BAFF"])

    my_circle=plt.Circle((0,0),0.5,color="white")
    ax[i].set_title(f"Tasa de mortalidad de {leyendas[i]}")

    ax[i].add_artist(my_circle)
    
ax[1].text(0, 2, "Mujeres y niños primero",
        fontsize=24, horizontalalignment="center")
ax[1].text(0,-2,"La tasa de mortalidad es mucho más elevada en el caso de los hombres:\nSolo sobrevivió 1 de cada 6 aproximadamente",
        fontsize=16, horizontalalignment="center");

fig.savefig("data/2.png", bbox_inches='tight')

# %%
# 3

data = df_titanic.groupby("class")["alive"].value_counts()

fig,ax = plt.subplots(1,3,figsize = (18,4))

leyendas = ["Primera Clase", "Segunda Clase", "Tercera Clase"]

for i in range(int(len(data.values)/2)):
    ax[i].pie(data.values[i*2:(i+1)*2],
            labels=["No sobrevivieron", "Sobrevivieron"],
            autopct='%.2f%%', startangle= 90,
            colors=["#FF4500","#00BAFF"])

    my_circle=plt.Circle((0,0),0.5,color="white")
    ax[i].set_title(f"Tasa de mortalidad en {leyendas[i]}")

    ax[i].add_artist(my_circle)
    
ax[1].text(0, 2, "Poderoso caballero es Don Dinero",
        fontsize=24, horizontalalignment="center")
ax[1].text(0,-2,"La tasa de mortalidad es mucho más elevada entre los pasajeros de tercera clase:\nSolo sobrevivió 1 de cada 4 aproximadamente",
        fontsize=16, horizontalalignment="center");

fig.savefig("data/3.png", bbox_inches='tight')

# %%
# 4

data = df_titanic.groupby(["who","class_reduced"])["alive"].value_counts()[["child","woman"]].sort_index()

fig,ax = plt.subplots(2,2,figsize = (12,12))

leyendas_who = ["niños", "mujeres"]
who = ["child", "woman"]
leyendas_class = ["Tercera", "Primera o Segunda"]
class_reduced = ["Third", "not_third"]

for k, (i,j,w,c) in enumerate([(0, 0, "child", "Third"), (0, 1, "child", "not_third"), (1, 0, "woman", "Third"), (1, 1, "woman", "not_third")]):
    ax[i,j].pie(data[w][c],
            labels=["No sobrevivieron", "Sobrevivieron"],
            autopct='%.2f%%', startangle= 90,
            colors=["#FF4500","#00BAFF"])

    my_circle=plt.Circle((0,0),0.5,color="white")
    ax[i,j].set_title(f"Tasa de mortalidad de {leyendas_who[i]} en {leyendas_class[j]} clase")

    ax[i,j].add_artist(my_circle)
    
fig.suptitle("Ricos primero, mujeres y niños después",
        fontsize=24, horizontalalignment="center");

fig.savefig("data/4.png", bbox_inches='tight')

# %%
# 5

data = df_titanic.groupby(["class_reduced", "embark_town"])["alive"].value_counts().sort_index()

fig,ax = plt.subplots(2,3,figsize = (24,16))

leyendas_embark_town = df_titanic.embark_town.unique()
embark_town = df_titanic.embark_town.unique()
leyendas_class = ["Tercera", "Primera o Segunda"]
class_reduced = ["Third", "not_third"]

for k, (i,j,w,c) in enumerate([(0, 0, "Third", "Cherbourg"), (0, 1, "Third", "Queenstown"), (0, 2, "Third", "Southampton"),
                               (1, 0, "not_third", "Cherbourg"), (1, 1, "not_third", "Queenstown"), (1, 2, "not_third", "Southampton")]):
    ax[i,j].pie(data[w][c],
            labels=["No sobrevivieron", "Sobrevivieron"],
            autopct='%.2f%%', startangle= 90,
            colors=["#FF4500","#00BAFF"])

    my_circle=plt.Circle((0,0),0.5,color="white")
    ax[i,j].set_title(f"Tasa de mortalidad\nde viajeros de {c}\nen {leyendas_class[i]} clase")

    ax[i,j].add_artist(my_circle)
    
fig.suptitle("No importa de dónde vengas: mientras pagues, te salvas",
        fontsize=24, horizontalalignment="center");

fig.savefig("data/5.png", bbox_inches='tight')
